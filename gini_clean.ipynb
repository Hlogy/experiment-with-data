# %%
import pandas as pd

# %%
data = pd.read_excel('Gini.xlsx')

# %%
data
# Out:
#           year          1961      1962      1963      1964      1965  \
# 0      country     gini_disp       NaN       NaN       NaN       NaN
# 1    Argentina  0.3596764603  0.357685  0.356529  0.355791  0.356820
# 2     Botswana             0  0.000000  0.000000  0.000000  0.000000
# 3       Brazil  0.4993695074  0.500768  0.502024  0.502061  0.503268
# 4         Chad           NaN       NaN       NaN       NaN       NaN
# 5        Chile           NaN       NaN       NaN       NaN       NaN
# 6        China           NaN       NaN       NaN       NaN       NaN
# 7      Ecuador           NaN       NaN       NaN       NaN       NaN
# 8      Hungary           NaN  0.248479  0.246018  0.242838  0.240887
# 9        India           NaN       NaN       NaN       NaN       NaN
# 10       Kenya           NaN       NaN       NaN       NaN       NaN
# 11     Lesotho           NaN       NaN       NaN       NaN       NaN
# 12      Malawi           NaN       NaN       NaN       NaN       NaN
# ...

# %%
data.drop(data.iloc[:, 1:44], axis = 1, inplace = True) 
data
# Out:
#           year      2004      2005      2006      2007      2008      2009  \
# 0      country       NaN       NaN       NaN       NaN       NaN       NaN
# 1    Argentina  0.452966  0.442450  0.432889  0.422866  0.413669  0.407890
# 2     Botswana  0.585215  0.584953  0.584686  0.584680  0.584762  0.584536
# 3       Brazil  0.509188  0.505514  0.502698  0.492670  0.484497  0.478767
# 4         Chad  0.424023  0.425148  0.427591  0.426260  0.426749  0.427589
# 5        Chile  0.492931  0.487240  0.480810  0.478965  0.476601  0.474623
# 6        China  0.417496  0.419426  0.422826  0.424862  0.427811  0.427153
# 7      Ecuador  0.488626  0.483989  0.478924  0.472173  0.463364  0.453907
# 8      Hungary  0.277325  0.275923  0.272970  0.271036  0.270137  0.271007
# 9        India  0.475990  0.477169  0.476792  0.478751  0.481493  0.484761
# 10       Kenya  0.470502  0.469579  0.470015  0.467160  0.466891  0.467044
# ...

# %%
data = data.rename(columns={'year': 'country'}, index={'ONE': 'one'})

# %%
data
# Out:
#        country      2004      2005      2006      2007      2008      2009  \
# 0      country       NaN       NaN       NaN       NaN       NaN       NaN
# 1    Argentina  0.452966  0.442450  0.432889  0.422866  0.413669  0.407890
# 2     Botswana  0.585215  0.584953  0.584686  0.584680  0.584762  0.584536
# 3       Brazil  0.509188  0.505514  0.502698  0.492670  0.484497  0.478767
# 4         Chad  0.424023  0.425148  0.427591  0.426260  0.426749  0.427589
# 5        Chile  0.492931  0.487240  0.480810  0.478965  0.476601  0.474623
# 6        China  0.417496  0.419426  0.422826  0.424862  0.427811  0.427153
# 7      Ecuador  0.488626  0.483989  0.478924  0.472173  0.463364  0.453907
# 8      Hungary  0.277325  0.275923  0.272970  0.271036  0.270137  0.271007
# 9        India  0.475990  0.477169  0.476792  0.478751  0.481493  0.484761
# 10       Kenya  0.470502  0.469579  0.470015  0.467160  0.466891  0.467044
# ...

# %%
data.drop([0], inplace = True)

# %%
data.drop(data.columns[[13,14,15,16]], axis=1, inplace = True)

# %%
data
# Out:
#        country      2004      2005      2006      2007      2008      2009  \
# 1    Argentina  0.452966  0.442450  0.432889  0.422866  0.413669  0.407890
# 2     Botswana  0.585215  0.584953  0.584686  0.584680  0.584762  0.584536
# 3       Brazil  0.509188  0.505514  0.502698  0.492670  0.484497  0.478767
# 4         Chad  0.424023  0.425148  0.427591  0.426260  0.426749  0.427589
# 5        Chile  0.492931  0.487240  0.480810  0.478965  0.476601  0.474623
# 6        China  0.417496  0.419426  0.422826  0.424862  0.427811  0.427153
# 7      Ecuador  0.488626  0.483989  0.478924  0.472173  0.463364  0.453907
# 8      Hungary  0.277325  0.275923  0.272970  0.271036  0.270137  0.271007
# 9        India  0.475990  0.477169  0.476792  0.478751  0.481493  0.484761
# 10       Kenya  0.470502  0.469579  0.470015  0.467160  0.466891  0.467044
# 11     Lesotho  0.509925  0.508952  0.508195  0.507159  0.505095  0.505016
# ...

# %%
data.set_index(['country'])
# Out:
#                 2004      2005      2006      2007      2008      2009  \
# country
# Argentina   0.452966  0.442450  0.432889  0.422866  0.413669  0.407890
# Botswana    0.585215  0.584953  0.584686  0.584680  0.584762  0.584536
# Brazil      0.509188  0.505514  0.502698  0.492670  0.484497  0.478767
# Chad        0.424023  0.425148  0.427591  0.426260  0.426749  0.427589
# Chile       0.492931  0.487240  0.480810  0.478965  0.476601  0.474623
# China       0.417496  0.419426  0.422826  0.424862  0.427811  0.427153
# Ecuador     0.488626  0.483989  0.478924  0.472173  0.463364  0.453907
# Hungary     0.277325  0.275923  0.272970  0.271036  0.270137  0.271007
# India       0.475990  0.477169  0.476792  0.478751  0.481493  0.484761
# Kenya       0.470502  0.469579  0.470015  0.467160  0.466891  0.467044
# Lesotho     0.509925  0.508952  0.508195  0.507159  0.505095  0.505016
# Malawi      0.463758  0.460884  0.459149  0.458015  0.457522  0.458489
# ...

# %%
data.to_excel("gini_clean.xlsx")
